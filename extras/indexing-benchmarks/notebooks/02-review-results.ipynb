# %% [markdown]
# # Stage 4: Review Benchmark Results & Visualizations
#
# Inspects 5x5 grid metrics, confidence intervals, FAISS latency, and per-query retrieval logs.

# %%
import json
from pathlib import Path
import pandas as pd

# Locate results file
res_file = None
for p in [Path("results/indexing_comparison_results.json"), Path("../results/indexing_comparison_results.json"), Path("extras/indexing-benchmarks/results/indexing_comparison_results.json")]:
    if p.is_file():
        res_file = p
        break

if res_file:
    report = json.loads(res_file.read_text(encoding="utf-8"))
    grid_df = pd.DataFrame(report["factorial_grid_dev_results"])
    print("Top 5 Factorial Configurations on Development Set:")
    display(grid_df.head(5))
else:
    print("No results file found. Run 01-run-benchmark.ipynb first.")
